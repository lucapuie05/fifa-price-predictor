# %% [markdown]
# ## Import Dataset and quick visualisation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from IPython.display import display

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r"D:/fifa-price-predictor/data/raw/FIFA_players_21.csv")

# %%
df.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05
# 2           J. Oblak                            Jan Oblak   27  1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31  1988-08-21
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  1992-02-05
#
#    height_cm  weight_kg nationality            club_name  \
# 0        170         72   Argentina         FC Barcelona
# ...

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg   league_rank  \
# count   18944.000000  18944.000000  18944.000000  18944.000000  18719.000000
# mean   226242.402872     25.225823    181.190773     75.016892      1.357070
# std     27171.091056      4.697354      6.825672      7.057140      0.739327
# min        41.000000     16.000000    155.000000     50.000000      1.000000
# 25%    210030.500000     21.000000    176.000000     70.000000      1.000000
# 50%    232314.500000     25.000000    181.000000     75.000000      1.000000
# 75%    246760.250000     29.000000    186.000000     80.000000      1.000000
# max    258970.000000     53.000000    206.000000    110.000000      4.000000
#
#             overall     potential     value_eur       wage_eur  \
# count  18944.000000  18944.000000  1.894400e+04   18944.000000
# mean      65.677787     71.086729  2.224813e+06    8675.852513
# std        7.002278      6.109985  5.102486e+06   19654.774894
# ...

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Columns: 106 entries, sofifa_id to rb
# dtypes: float64(18), int64(44), object(44)
# memory usage: 15.3+ MB
# None

# %% [markdown]
# ## Preparation for Data Cleaning and EDA

# %%
df.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05
# 2           J. Oblak                            Jan Oblak   27  1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31  1988-08-21
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  1992-02-05
#
#    height_cm  weight_kg nationality            club_name  \
# 0        170         72   Argentina         FC Barcelona
# ...

# %%
print(df.isnull().sum())
# Out:
# sofifa_id                         0
# player_url                        0
# short_name                        0
# long_name                         0
# age                               0
# dob                               0
# height_cm                         0
# weight_kg                         0
# nationality                       0
# club_name                       225
# league_name                     225
# league_rank                     225
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# real_face                         0
# release_clause_eur              995
# player_tags                   17536
# ...

# %%
df.drop(columns=['player_url', 'short_name', 'dob', 'nationality', 'league_name', 'real_face', 'team_jersey_number', 'nation_jersey_number', 'sofifa_id'], axis= 1, inplace= True)

# %%
df.head(5)
# Out:
#                              long_name  age  height_cm  weight_kg  \
# 0       Lionel Andrés Messi Cuccittini   33        170         72
# 1  Cristiano Ronaldo dos Santos Aveiro   35        187         83
# 2                            Jan Oblak   27        188         87
# 3                   Robert Lewandowski   31        184         80
# 4        Neymar da Silva Santos Júnior   28        175         68
#
#              club_name  league_rank  overall  potential  value_eur  wage_eur  \
# 0         FC Barcelona          1.0       93         93   67500000    560000
# 1             Juventus          1.0       92         92   46000000    220000
# 2      Atlético Madrid          1.0       91         93   75000000    125000
# 3    FC Bayern München          1.0       91         91   80000000    240000
# 4  Paris Saint-Germain          1.0       91         91   90000000    270000
#
#   player_positions preferred_foot  international_reputation  weak_foot  \
# ...

# %%
df.drop(df.columns[-26:], axis= 1, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Data columns (total 71 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   long_name                   18944 non-null  object
#  1   age                         18944 non-null  int64
#  2   height_cm                   18944 non-null  int64
#  3   weight_kg                   18944 non-null  int64
#  4   club_name                   18719 non-null  object
#  5   league_rank                 18719 non-null  float64
#  6   overall                     18944 non-null  int64
#  7   potential                   18944 non-null  int64
#  8   value_eur                   18944 non-null  int64
#  9   wage_eur                    18944 non-null  int64
#  10  player_positions            18944 non-null  object
#  11  preferred_foot              18944 non-null  object
#  12  international_reputation    18944 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# long_name                         0
# age                               0
# height_cm                         0
# weight_kg                         0
# club_name                       225
# league_rank                     225
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# release_clause_eur              995
# player_tags                   17536
# team_position                   225
# loaned_from                   18186
# joined                          983
# contract_valid_until            225
# nation_position               17817
# pace                           2083
# shooting                       2083
# ...

# %%
df.drop(columns=['loaned_from', 'player_tags', 'nation_position', 'defending_marking'], axis= 1, inplace= True)

# %%
((df['player_positions'] == 'GK') & (df['gk_diving'].notna())).sum()
# Out:
# np.int64(2083)

# %% [markdown]
# ## Spliting the Dataset in Field Player and Gk

# %%
df.columns.to_list()
# Out:
# ['long_name',
#  'age',
#  'height_cm',
#  'weight_kg',
#  'club_name',
#  'league_rank',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'release_clause_eur',
#  'team_position',
#  'joined',
#  'contract_valid_until',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
# ...

# %%
gk_columns = ['goalkeeping_diving',
 'goalkeeping_handling',
 'goalkeeping_kicking',
 'goalkeeping_positioning',
 'goalkeeping_reflexes', 'long_name',
 'age',
 'height_cm',
 'weight_kg',
 'club_name',
 'league_rank',
 'overall',
 'potential',
 'value_eur',
 'wage_eur',
 'player_positions',
 'preferred_foot',
 'international_reputation',
 'weak_foot', 'body_type',
 'release_clause_eur',
 'team_position',
 'joined',
 'contract_valid_until', 'physic',
 'gk_diving',
 'gk_handling',
 'gk_kicking',
 'gk_reflexes',
 'gk_speed',
 'gk_positioning',
 'player_traits', 'skill_fk_accuracy',
 'skill_long_passing',
 'skill_ball_control', 'movement_agility',
 'movement_reactions',
 'movement_balance', 'mentality_vision',
 'mentality_penalties',
 'mentality_composure']

# %%
df_gk = df[gk_columns].copy()

# %%
df_gk.head(5)
# Out:
#    goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                   6                    11                   15
# 1                   7                    11                   15
# 2                  87                    92                   78
# 3                  15                     6                   12
# 4                   9                     9                   15
#
#    goalkeeping_positioning  goalkeeping_reflexes  \
# 0                       14                     8
# 1                       14                    11
# 2                       90                    90
# 3                        8                    10
# 4                       15                    11
#
#                              long_name  age  height_cm  weight_kg  \
# 0       Lionel Andrés Messi Cuccittini   33        170         72
# 1  Cristiano Ronaldo dos Santos Aveiro   35        187         83
# 2                            Jan Oblak   27        188         87
# ...

# %%
df_player = df

# %%
df_player.head(5)
# Out:
#                              long_name  age  height_cm  weight_kg  \
# 0       Lionel Andrés Messi Cuccittini   33        170         72
# 1  Cristiano Ronaldo dos Santos Aveiro   35        187         83
# 2                            Jan Oblak   27        188         87
# 3                   Robert Lewandowski   31        184         80
# 4        Neymar da Silva Santos Júnior   28        175         68
#
#              club_name  league_rank  overall  potential  value_eur  wage_eur  \
# 0         FC Barcelona          1.0       93         93   67500000    560000
# 1             Juventus          1.0       92         92   46000000    220000
# 2      Atlético Madrid          1.0       91         93   75000000    125000
# 3    FC Bayern München          1.0       91         91   80000000    240000
# 4  Paris Saint-Germain          1.0       91         91   90000000    270000
#
#   player_positions preferred_foot  international_reputation  weak_foot  \
# ...

# %%
df_player.to_csv(r"D:/fifa-price-predictor/data/raw/players_dataset.csv")
df_gk.to_csv(r"D:/fifa-price-predictor/data/raw/gk_dataset.csv")
